# %% [markdown]
# # Reversal Symmetry for Simple Stable Voting
#
# This notebook contains the code used to verify the reversal symmetry property for simple stable voting (SSV) as described in Section 5 of the paper "Stable Voting and the Splitting of Cycles".

# %%
# %pip install python-sat
# %pip install pref_voting
# Out:
# Requirement already satisfied: python-sat in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (1.8.dev17)
# Requirement already satisfied: six in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from python-sat) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pref_voting in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (1.16.22)
# Requirement already satisfied: filelock<4.0.0,>=3.12.2 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (3.18.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.5.2 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (3.10.3)
# Requirement already satisfied: nashpy<0.0.41,>=0.0.40 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (0.0.40)
# Requirement already satisfied: networkx<4.0,>=3.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (3.5)
# Requirement already satisfied: numba<0.62.0,>=0.61.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (0.61.2)
# Requirement already satisfied: ortools<10.0.0,>=9.8.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (9.14.6206)
# Requirement already satisfied: pathos<0.4.0,>=0.3.3 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (0.3.4)
# Requirement already satisfied: preflibtools<3.0.0,>=2.0.22 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (2.0.33)
# Requirement already satisfied: prefsampling<0.2.0,>=0.1.16 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (0.1.24)
# Requirement already satisfied: random2<2.0.0,>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (1.0.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (1.16.0)
# Requirement already satisfied: seaborn<0.14.0,>=0.13.2 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (0.13.2)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pref_voting) (0.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.5.2->pref_voting) (2.9.0.post0)
# Requirement already satisfied: deprecated>=1.2.14 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from nashpy<0.0.41,>=0.0.40->pref_voting) (1.2.18)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from numba<0.62.0,>=0.61.0->pref_voting) (0.44.0)
# Requirement already satisfied: absl-py>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from ortools<10.0.0,>=9.8.0->pref_voting) (2.3.1)
# Requirement already satisfied: pandas>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from ortools<10.0.0,>=9.8.0->pref_voting) (2.3.1)
# Requirement already satisfied: protobuf<6.32,>=6.31.1 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from ortools<10.0.0,>=9.8.0->pref_voting) (6.31.1)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from ortools<10.0.0,>=9.8.0->pref_voting) (4.14.1)
# Requirement already satisfied: immutabledict>=3.0.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from ortools<10.0.0,>=9.8.0->pref_voting) (4.2.1)
# Requirement already satisfied: ppft>=1.7.7 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pathos<0.4.0,>=0.3.3->pref_voting) (1.7.7)
# Requirement already satisfied: dill>=0.4.0 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pathos<0.4.0,>=0.3.3->pref_voting) (0.4.0)
# Requirement already satisfied: pox>=0.3.6 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pathos<0.4.0,>=0.3.3->pref_voting) (0.3.6)
# Requirement already satisfied: multiprocess>=0.70.18 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pathos<0.4.0,>=0.3.3->pref_voting) (0.70.18)
# Requirement already satisfied: pulp in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from preflibtools<3.0.0,>=2.0.22->pref_voting) (3.2.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from deprecated>=1.2.14->nashpy<0.0.41,>=0.0.40->pref_voting) (1.17.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pandas>=2.0.0->ortools<10.0.0,>=9.8.0->pref_voting) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from pandas>=2.0.0->ortools<10.0.0,>=9.8.0->pref_voting) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.5.2->pref_voting) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pysat.formula import IDPool
from pysat.solvers import Solver
import itertools
import functools
from pref_voting.weighted_majority_graphs import MarginGraph
from pref_voting.margin_based_methods import split_cycle, stable_voting, simple_stable_voting

# %%
for n in range(2, 11):
    print(f"Encoding {n}", flush=True)
    
    pool = IDPool()
    s = Solver(use_timer=True)
    
    # "precedes" variable definitions
    def lt(a, b, c, d, reverse):
        if reverse:
            return lt(c, d, a, b, False)
        if a == b or c == d:
            raise ValueError(f'Edges may not be self-loops.')
        if a == c and b == d:
            raise ValueError('Edges must be distinct.')
        if (a > d) or (a == d and b > c):
            return lt(d, c, b, a, False)
        return pool.id(f'{a}{b}{c}{d}')
    
    # "SSV" variable definitions
    def SSV(V, x, reverse):
        return pool.id(f"{x}win{''.join(str(v) for v in V)}{"rev" if reverse else ""}")
    
    # all undirected edges between a collection of nodes 
    def edges(V=range(n)):
        return itertools.permutations(V, 2)
    
    def ordering():
        added = set()
        for ((a, b), (c, d), (e, f)) in itertools.permutations(edges(), 3):
            first = lt(a, b, c, d, False)
            second = lt(c, d, e, f, False)
            if (first, second) not in added:
                added.add((first, second))
                s.add_clause([-first, -second, lt(a, b, e, f, False)])
        for ((a, b), (c, d)) in itertools.permutations(edges(), 2):
            s.add_clause([lt(a, b, c, d, False), lt(b, a, d, c, False)])
            s.add_clause([-lt(a, b, c, d, False), -lt(b, a, d, c, False)])
    
    def removed(V, x):
        return tuple(v for v in V if v != x)
    
    def SSV_conditions():
        for rev in [False, True]:
            for V in itertools.chain.from_iterable(itertools.combinations(range(n), r) for r in range(1, n+1)):
                s.add_clause([SSV(V, x, rev) for x in V])
        
                for (x, y) in edges(V):
                    s.add_clause([-SSV(V, x, rev), -SSV(V, y, rev)])
                
                for (a, b) in edges(V):
                    clause = [-SSV(removed(V, b), a, rev), SSV(V, a, rev)]
                    for (c, d) in edges(V):
                        if c != a or d != b:
                            # tseitin iff -SSV((removed(V, d), c)) \/ lt(c, d, a, b)
                            tseitin = pool.id(f"t{a}{b}{c}{d}in{''.join(str(x) for x in V)}{"rev" if rev else ""}")
                            s.add_clause([-SSV(removed(V, d), c, rev), lt(c, d, a, b, rev), -tseitin])
                            s.add_clause([SSV(removed(V, d), c, rev), tseitin])
                            s.add_clause([-lt(c, d, a, b, rev), tseitin])
                            clause.append(-tseitin)
                    s.add_clause(clause)
    
    
    def symmetry_breaking():
        for i in range(n):
            V = tuple(range(i+1))
            s.add_clause([SSV(V, 0, False)])
            for (c, d) in edges(V):
                if c != 0 or d != i:
                    s.add_clause([-SSV(removed(V, d), c, False), lt(c, d, 0, i, False)])
    
    
    def check_model(model):
        def compare(x, y):
            (a, b) = x
            (c, d) = y
            return 1 if lt(a, b, c, d, False) in model else -1 # descending
        edge_list = sorted(edges(), key=functools.cmp_to_key(compare))
        max_weight = (n * (n - 1) // 2)
        return MarginGraph(list(range(n)), 
                           [(edge_list[i][0], edge_list[i][1], max_weight - i) for i in range(len(edge_list) // 2)])
    
    
    # add the clauses
    ordering()
    SSV_conditions()
    symmetry_breaking()                             
    s.add_clause([SSV(tuple(range(n)), 0, True)]) # 0 is also the winner in the reverse. 

    print(s.nof_clauses(), flush=True)
    print(f"Starting {n}", flush=True)
    
    if s.solve(): # takes around 45 seconds for n=7.
        result = check_model(s.get_model())
        result.display()
        print(f"Time: {s.time()}")
        print(f"Split Cycle Winners: {split_cycle(result)}")
        print(f"Stable Voting Winner: {stable_voting(result)}")
        print(f"Simple Stable Voting Winner: {simple_stable_voting(result)}", flush=True)
        break
    else:
        print(f"No counterexamples of size {n}", flush=True)
# Out:
# Encoding 2
# 22
# Starting 2
# No counterexamples of size 2
# Encoding 3
# 444
# Starting 3
# No counterexamples of size 3
# Encoding 4
# 3371
# Starting 4
# No counterexamples of size 4
# Encoding 5
# 16441
# Starting 5
# No counterexamples of size 5
# Encoding 6
# 62688
# Starting 6
# No counterexamples of size 6
# Encoding 7
# 206970
# Starting 7
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 92
#      89 print(s.nof_clauses(), flush=True)
#      90 print(f"Starting {n}", flush=True)
# ---> 92 if s.solve(): # takes around 45 seconds for n=7.
#      93     result = check_model(s.get_model())
#      94     result.display()
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages/pysat/solvers.py:762, in Solver.solve(self, assumptions)
#     726 """
#     727     This method is used to check satisfiability of a CNF formula given
#     728     to the solver (see methods :meth:`add_clause` and
#    (...)    758         >>> s.delete()
#     759 """
#     761 if self.solver:
# --> 762     return self.solver.solve(assumptions)
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.5/libexec/lib/python3.13/site-packages/pysat/solvers.py:6704, in Minisat22.solve(self, assumptions)
#    6701 if self.use_timer:
#    6702      start_time = process_time()
# -> 6704 self.status = pysolvers.minisat22_solve(self.minisat, assumptions,
#    6705         int(MainThread.check()))
#    6707 if self.use_timer:
#    6708     self.call_time = process_time() - start_time
#
# error: Caught keyboard interrupt
